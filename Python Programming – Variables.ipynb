# %% [markdown]
# ## Section A

# %%
name=input("Enter your Name")
print(name)
# Out:
# Enter your Name Chamindu
# Chamindu

# %%
x=int(input("Enter Number 1"))
y=int(input("Enter Number 2"))
sum=x+y
print(sum)
# Out:
# Enter Number 1 30
# Enter Number 2 40
# 70

# %%
age=int(input("Enter your Age"))
print(f"I am {age} years old")
# Out:
# Enter your Age 20
# I am 20 years old

# %%
sch_name=("Mahinda Rajapaksha College")
print(sch_name)
# Out:
# Mahinda Rajapaksha College

# %% [markdown]
# ## Section B

# %%
byr=int(2005)
cyr=int(2025)
age=cyr-byr
print(f"You are {age} years old")
# Out:
# You are 20 years old

# %%
celsius = 37
fahrenheit = (celsius * 9) / 5 + 32
print("Celsius:", celsius)
print("Fahrenheit:", fahrenheit)
# Out:
# Celsius: 37
# Fahrenheit: 98.6

# %%
rad=int(input("Enter the radial length"))
area=2*3.14*rad
print(area)
# Out:
# Enter the radial length 7
# 43.96

# %%
days=30
weeks=days//7
rem=days%7
print(f"{days} days = {weeks} weeks and {rem} days")
# Out:
# 30 days = 4 weeks and 2 days

# %% [markdown]
# ## Section C

# %%
hrs=int(input("Enter the number of hours worked"))
rate=300
total=hrs*rate
print("RS.",total)
# Out:
# Enter the number of hours worked 3
# RS. 900

# %%
byr=int(2005)
cyr=int(2025)
age=cyr-byr
print(f"You are {age} years old")
# Out:
# You are 20 years old
